# %%
using Plots, DataFrames, VegaLite

# %%
df = DataFrame(series1 = 1:10, series2 = sin.(1:10), series3=rand(10))
# Out:
# 10×3 DataFrame
#  Row │ series1  series2    series3
#      │ Int64    Float64    Float64
# ─────┼────────────────────────────────
#    1 │       1   0.841471  0.963494
#    2 │       2   0.909297  0.462992
#    3 │       3   0.14112   0.00826007
#    4 │       4  -0.756802  0.453097
#    5 │       5  -0.958924  0.118376
#    6 │       6  -0.279415  0.996548
#    7 │       7   0.656987  0.754652
#    8 │       8   0.989358  0.462154
#    9 │       9   0.412118  0.124737
#   10 │      10  -0.544021  0.848654

# %%
df |>
@vlplot(
    :point,
    x= :series2,
    y= :series3,
    color=:series1,
    width=400,
    height=400
)
# Out:
# @vlplot(
#     width=400,
#     height=400,
#     mark="point",
#     encoding={
#         x={
#             field="series2"
#         },
#         y={
#             field="series3"
#         },
#         color={
#             field="series1"
#         }
#     },
#     data={
#         values=...
#     }
# )
